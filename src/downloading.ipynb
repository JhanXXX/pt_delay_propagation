# %%
from src.data_downloader import prepare_sl_gtfs_realtime
from src.data_downloader import prepare_sl_gtfs_static
"""api_key = ""

year = "2025"
month = "04"
hours = ["07","08","09","16","17","18"]


day = "15"
hours = ["16","17","18"]
for hour in hours:
    prepare_sl_gtfs_realtime(api_key,year,month,day,hour)
    
day = "16"
hours = ["07","08","09","16","17","18"]
for hour in hours:
    prepare_sl_gtfs_realtime(api_key,year,month,day,hour)


day = "17"
for hour in hours:
    prepare_sl_gtfs_realtime(api_key,year,month,day,hour)

days = ["15","16","17"]
for day in days:
    prepare_sl_gtfs_static(api_key,year,month,day)

### ------

month = "05"
day = "05"
for hour in hours:
    prepare_sl_gtfs_realtime(api_key,year,month,day,hour)
day = "06"
for hour in hours:
    prepare_sl_gtfs_realtime(api_key,year,month,day,hour)
day = "07"
for hour in hours:
    prepare_sl_gtfs_realtime(api_key,year,month,day,hour)
day = "08"
for hour in hours:
    prepare_sl_gtfs_realtime(api_key,year,month,day,hour)

days = ["05","06","07","08"]
for day in days:
    prepare_sl_gtfs_static(api_key,year,month,day)    """
# Out:
# failed: 2025-04-15. 400
# failed: 2025-04-15. 400
# failed: 2025-04-15. 400
# failed: 2025-04-16. 400
# failed: 2025-04-16. 400
# 2025-04-16 download suceeded!
# 2025-04-16 download suceeded!
# 2025-04-16 download suceeded!
# 2025-04-16 download suceeded!
# failed:  500
# download 2025-04-16 suceeded!
# download 2025-04-17 suceeded!
# 2025-05-05 download suceeded!
# 2025-05-05 download suceeded!
# 2025-05-05 download suceeded!
# 2025-05-05 download suceeded!
# 2025-05-05 download suceeded!
# 2025-05-05 download suceeded!
# 2025-05-06 download suceeded!
# 2025-05-06 download suceeded!
# 2025-05-06 download suceeded!
# 2025-05-06 download suceeded!
# 2025-05-06 download suceeded!
# 2025-05-06 download suceeded!
# 2025-05-07 download suceeded!
# 2025-05-07 download suceeded!
# 2025-05-07 download suceeded!
# 2025-05-07 download suceeded!
# 2025-05-07 download suceeded!
# 2025-05-07 download suceeded!
# 2025-05-08 download suceeded!
# 2025-05-08 download suceeded!
# ...
