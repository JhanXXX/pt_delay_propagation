# %%
import sqlite3
import pandas as pd
from pathlib import Path
import os
db_path="/example_data/example.db"
output_dir = "/output"
os.makedirs(Path(output_dir),exist_ok=True)
conn = sqlite3.connect(db_path)
pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", conn)
# Out:
#                     name
# 0        TripUpdates_poi
# 1  TripUpdates_poi_joint
# 2             stop_pairs

# %%
from src.poi_joint import prepare_stop_pairs
ob_window=10*60
gap=1
prepare_stop_pairs(db_path, gap, ob_window)
# Out:
# created index for (trip_id, vehicle_id, start_date, stop_sequence)

# %%
df_pairs = pd.read_sql_query("SELECT * FROM stop_pairs limit 5", conn)
for column in df_pairs.columns:
    print(column)
# Out:
# trip_id
# start_date
# vehicle_id
# stop_i
# seq_i
# arr_delay_i
# dep_delay_i
# arr_time_i
# duration_i
# his_dwell_count_i
# his_avg_delay_i
# his_avg_dwell_i
# stop_j
# seq_j
# arr_delay_j
# dep_delay_j
# arr_time_j
# duration_j
# travel_time
# delay_change
# hour_of_day
# day_of_week

# %%
import sqlite3
conn = sqlite3.connect(db_path)

# Basic statistics
stats_query = """
SELECT 
    COUNT(*) as total_records,
    COUNT(DISTINCT trip_id) as n_trips,
    COUNT(DISTINCT stop_id) as n_stops,
    COUNT(DISTINCT start_date) as n_days,
    MIN(start_date) as first_date,
    MAX(start_date) as last_date
FROM TripUpdates_poi
"""
stats = pd.read_sql(stats_query, conn)
print(stats.to_string(index=False))
# Out:
#  total_records  n_trips  n_stops  n_days first_date last_date
#          76595     2447      804       4   20250505  20250508

# %%
# Delay statistics - fixed for SQLite
delay_stats = """
SELECT 
    AVG(arr_delay) as mean_delay,
    MIN(arr_delay) as min_delay,
    MAX(arr_delay) as max_delay,
    COUNT(CASE WHEN arr_delay > 60 THEN 1 END) as late_count,
    COUNT(CASE WHEN arr_delay < -60 THEN 1 END) as early_count,
    COUNT(CASE WHEN arr_delay BETWEEN -60 AND 60 THEN 1 END) as ontime_count,
    COUNT(*) as total_count,
    ROUND(100.0 * COUNT(CASE WHEN arr_delay > 60 THEN 1 END) / COUNT(*), 2) as late_pct,
    ROUND(100.0 * COUNT(CASE WHEN arr_delay < -60 THEN 1 END) / COUNT(*), 2) as early_pct,
    ROUND(100.0 * COUNT(CASE WHEN arr_delay BETWEEN -60 AND 60 THEN 1 END) / COUNT(*), 2) as ontime_pct
FROM TripUpdates_poi
WHERE arr_delay IS NOT NULL
"""

print("\nDelay Statistics:")
print("(Negative = Early, Positive = Late, unit: seconds)")
delay_df = pd.read_sql(delay_stats, conn)
print(delay_df.to_string(index=False))

# Compute std using pandas
all_delays = pd.read_sql("SELECT arr_delay FROM TripUpdates_poi WHERE arr_delay IS NOT NULL", conn)
print(f"\nStandard Deviation of Delays: {all_delays['arr_delay'].std():.2f} seconds")
# Out:
# Delay Statistics:
# (Negative = Early, Positive = Late, unit: seconds)
#  mean_delay  min_delay  max_delay  late_count  early_count  ontime_count  total_count  late_pct  early_pct  ontime_pct
#  112.457092      -2709       7617       43335         7670         25590        76595     56.58      10.01       33.41
#
# Standard Deviation of Delays: 207.14 seconds

# %%
gap = 1
ob_window = 20*60
from src.statistical_learning import compare_methods
compare_methods(db_path, gap, output_dir)
# Out:
# created index for (trip_id, vehicle_id, start_date, stop_sequence)
# Loaded 67,634 observations
# Remained 67,634 observations after outlier filtering
# Treatment: delay_i (continuous, in seconds)
#   Mean: 117.77 seconds
#   Std: 199.02 seconds
#   Range: [-2709.00, 7222.00]
#
# Outcome: delay_j (continuous, in seconds)
#   Mean: 119.88 seconds
#   Std: 198.28 seconds
#
# ============================================================
# IDENTIFYING CONFOUNDERS
# ============================================================
#
# Confounders included:
#   - hour_of_day
#   - his_dwell_count_i
#   - his_avg_delay_i
#   - his_avg_dwell_i
#   - is_morning_peak
#   - is_evening_peak
#
# Clean dataset: 67,634 observations
#
# ============================================================
# METHOD 1: NAIVE COMPARISON (BASELINE)
# ============================================================
# Naive estimate: β = 0.9062
# Interpretation: Each 1-second increase in delay_i is associated
#                 with 0.9062 seconds increase in delay_j
#
# ============================================================
# METHOD 2: REGRESSION ADJUSTMENT
# ============================================================
# Regression-adjusted estimate: β = 0.9142
# Interpretation: Controlling for confounders, each 1-second increase
#                 in delay_i causes 0.9142 seconds increase in delay_j
#
# Regression coefficients:
#   hour_of_day: 7.9097
#   his_dwell_count_i: 0.0130
#   his_avg_delay_i: -8.3334
#   his_avg_dwell_i: -0.2674
#   is_morning_peak: 4.4053
#   is_evening_peak: -5.8205
#
# ============================================================
# METHOD 3: GENERALIZED PROPENSITY SCORE (GPS)
# ============================================================
# Reference: Hirano & Imbens (2004)
#
# Step 1: Estimating treatment model E[D|X]...
# Treatment model R²: 0.0578
# Residual std (σ): 193.19
#
# Step 2: Calculating Generalized Propensity Score...
# GPS range: [0.000000, 0.002065]
# Mean GPS: 0.001657
#
# Step 3: Trimming for common support...
# Common support: GPS in [0.000124, 0.002065]
# Observations retained: 64,256 (95.0%)
#
# === Analysis of Trimmed Observations ===
# Trimmed: 3,378 (5.0%)
# Trimmed mean delay_i: 390.11
# Trimmed mean delay_j: 395.48
# Retained mean delay_i: 103.46
# Retained mean delay_j: 105.39
#
# Step 4: Estimating dose-response function...
# GPS-adjusted estimate: β = 0.8439
# Interpretation: Balancing treatment assignment, each 1-second increase
#                 in delay_i causes 0.8439 seconds increase in delay_j
#
# Step 5: Estimating dose-response curve...
#
# ============================================================
# METHOD 4: DOUBLY ROBUST ESTIMATION (GPS + OUTCOME MODEL)
# ============================================================
#
# Step 1: Fitting outcome regression model E[Y|D,X]...
#
# Step 2: Computing doubly robust estimate...
# Doubly Robust estimate: β = 0.8481
#
# ============================================================
# COVARIATE BALANCE CHECK
# ============================================================
#
# Correlation between Treatment and Confounders:
# (Good balance: correlation close to 0 after GPS adjustment)
#        Confounder  Correlation_before  Correlation_after  Reduction
#       hour_of_day            0.010737           0.013047  -0.002310
# his_dwell_count_i            0.126945           0.159721  -0.032775
#   his_avg_delay_i            0.224178           0.299552  -0.075373
#   his_avg_dwell_i           -0.002091          -0.063758  -0.061667
#   is_morning_peak           -0.008288          -0.013349  -0.005061
#   is_evening_peak           -0.038868          -0.047794  -0.008926
#
# ============================================================
# SUMMARY: COMPARISON OF ALL METHODS
# ============================================================
#
#                                 Method  Coefficient β Controls Confounding Assumes linearity
#               1. Naive (No adjustment)       0.906195                   No               Yes
#           2. Regression (Linear model)       0.914191     Yes (parametric)               Yes
#         3. GPS (Nonparametric balance)       0.843898      Yes (balancing)     No (flexible)
# 4. Doubly Robust (GPS + Outcome model)       0.848140  Yes (doubly robust)         Partially
#
# Interpretation of coefficient β:
# Each 1-second increase in delay at stop i causes β seconds
# increase in delay at stop j (on average)

# %%
gap = 2
from src.statistical_learning import compare_methods
compare_methods(db_path, gap, output_dir)
# Out:
# created index for (trip_id, vehicle_id, start_date, stop_sequence)
# Loaded 59,883 observations
# Remained 59,883 observations after outlier filtering
# Treatment: delay_i (continuous, in seconds)
#   Mean: 119.25 seconds
#   Std: 198.51 seconds
#   Range: [-2709.00, 7222.00]
#
# Outcome: delay_j (continuous, in seconds)
#   Mean: 122.46 seconds
#   Std: 199.37 seconds
#
# ============================================================
# IDENTIFYING CONFOUNDERS
# ============================================================
#
# Confounders included:
#   - hour_of_day
#   - his_dwell_count_i
#   - his_avg_delay_i
#   - his_avg_dwell_i
#   - is_morning_peak
#   - is_evening_peak
#
# Clean dataset: 59,883 observations
#
# ============================================================
# METHOD 1: NAIVE COMPARISON (BASELINE)
# ============================================================
# Naive estimate: β = 0.8817
# Interpretation: Each 1-second increase in delay_i is associated
#                 with 0.8817 seconds increase in delay_j
#
# ============================================================
# METHOD 2: REGRESSION ADJUSTMENT
# ============================================================
# Regression-adjusted estimate: β = 0.8906
# Interpretation: Controlling for confounders, each 1-second increase
#                 in delay_i causes 0.8906 seconds increase in delay_j
#
# Regression coefficients:
#   hour_of_day: 7.5668
#   his_dwell_count_i: 3.4585
#   his_avg_delay_i: -11.3769
#   his_avg_dwell_i: -0.4292
#   is_morning_peak: 3.7197
#   is_evening_peak: -8.6557
#
# ============================================================
# METHOD 3: GENERALIZED PROPENSITY SCORE (GPS)
# ============================================================
# Reference: Hirano & Imbens (2004)
#
# Step 1: Estimating treatment model E[D|X]...
# Treatment model R²: 0.0597
# Residual std (σ): 192.49
#
# Step 2: Calculating Generalized Propensity Score...
# GPS range: [0.000000, 0.002073]
# Mean GPS: 0.001664
#
# Step 3: Trimming for common support...
# Common support: GPS in [0.000121, 0.002072]
# Observations retained: 56,887 (95.0%)
#
# === Analysis of Trimmed Observations ===
# Trimmed: 2,996 (5.0%)
# Trimmed mean delay_i: 389.19
# Trimmed mean delay_j: 391.58
# Retained mean delay_i: 105.03
# Retained mean delay_j: 108.29
#
# Step 4: Estimating dose-response function...
# GPS-adjusted estimate: β = 0.8082
# Interpretation: Balancing treatment assignment, each 1-second increase
#                 in delay_i causes 0.8082 seconds increase in delay_j
#
# Step 5: Estimating dose-response curve...
#
# ============================================================
# METHOD 4: DOUBLY ROBUST ESTIMATION (GPS + OUTCOME MODEL)
# ============================================================
#
# Step 1: Fitting outcome regression model E[Y|D,X]...
#
# Step 2: Computing doubly robust estimate...
# Doubly Robust estimate: β = 0.8180
#
# ============================================================
# COVARIATE BALANCE CHECK
# ============================================================
#
# Correlation between Treatment and Confounders:
# (Good balance: correlation close to 0 after GPS adjustment)
#        Confounder  Correlation_before  Correlation_after  Reduction
#       hour_of_day            0.019792           0.024736  -0.004943
# his_dwell_count_i            0.130167           0.166081  -0.035914
#   his_avg_delay_i            0.227533           0.301362  -0.073829
#   his_avg_dwell_i           -0.002198          -0.073579  -0.071381
#   is_morning_peak           -0.016154          -0.023407  -0.007253
#   is_evening_peak           -0.031453          -0.037283  -0.005830
#
# ============================================================
# SUMMARY: COMPARISON OF ALL METHODS
# ============================================================
#
#                                 Method  Coefficient β Controls Confounding Assumes linearity
#               1. Naive (No adjustment)       0.881695                   No               Yes
#           2. Regression (Linear model)       0.890640     Yes (parametric)               Yes
#         3. GPS (Nonparametric balance)       0.808180      Yes (balancing)     No (flexible)
# 4. Doubly Robust (GPS + Outcome model)       0.817969  Yes (doubly robust)         Partially
#
# Interpretation of coefficient β:
# Each 1-second increase in delay at stop i causes β seconds
# increase in delay at stop j (on average)

# %%
gap = 3
from src.statistical_learning import compare_methods
compare_methods(db_path, gap, output_dir)
# Out:
# created index for (trip_id, vehicle_id, start_date, stop_sequence)
# Loaded 52,778 observations
# Remained 52,778 observations after outlier filtering
# Treatment: delay_i (continuous, in seconds)
#   Mean: 120.72 seconds
#   Std: 198.14 seconds
#   Range: [-2275.00, 7222.00]
#
# Outcome: delay_j (continuous, in seconds)
#   Mean: 123.40 seconds
#   Std: 200.58 seconds
#
# ============================================================
# IDENTIFYING CONFOUNDERS
# ============================================================
#
# Confounders included:
#   - hour_of_day
#   - his_dwell_count_i
#   - his_avg_delay_i
#   - his_avg_dwell_i
#   - is_morning_peak
#   - is_evening_peak
#
# Clean dataset: 52,778 observations
#
# ============================================================
# METHOD 1: NAIVE COMPARISON (BASELINE)
# ============================================================
# Naive estimate: β = 0.8533
# Interpretation: Each 1-second increase in delay_i is associated
#                 with 0.8533 seconds increase in delay_j
#
# ============================================================
# METHOD 2: REGRESSION ADJUSTMENT
# ============================================================
# Regression-adjusted estimate: β = 0.8637
# Interpretation: Controlling for confounders, each 1-second increase
#                 in delay_i causes 0.8637 seconds increase in delay_j
#
# Regression coefficients:
#   hour_of_day: 8.1825
#   his_dwell_count_i: 5.4037
#   his_avg_delay_i: -14.0065
#   his_avg_dwell_i: -0.6483
#   is_morning_peak: 3.8224
#   is_evening_peak: -11.2883
#
# ============================================================
# METHOD 3: GENERALIZED PROPENSITY SCORE (GPS)
# ============================================================
# Reference: Hirano & Imbens (2004)
#
# Step 1: Estimating treatment model E[D|X]...
# Treatment model R²: 0.0609
# Residual std (σ): 192.01
#
# Step 2: Calculating Generalized Propensity Score...
# GPS range: [0.000000, 0.002078]
# Mean GPS: 0.001665
#
# Step 3: Trimming for common support...
# Common support: GPS in [0.000116, 0.002077]
# Observations retained: 50,146 (95.0%)
#
# === Analysis of Trimmed Observations ===
# Trimmed: 2,632 (5.0%)
# Trimmed mean delay_i: 393.65
# Trimmed mean delay_j: 386.14
# Retained mean delay_i: 106.40
# Retained mean delay_j: 109.61
#
# Step 4: Estimating dose-response function...
# GPS-adjusted estimate: β = 0.7641
# Interpretation: Balancing treatment assignment, each 1-second increase
#                 in delay_i causes 0.7641 seconds increase in delay_j
#
# Step 5: Estimating dose-response curve...
#
# ============================================================
# METHOD 4: DOUBLY ROBUST ESTIMATION (GPS + OUTCOME MODEL)
# ============================================================
#
# Step 1: Fitting outcome regression model E[Y|D,X]...
#
# Step 2: Computing doubly robust estimate...
# Doubly Robust estimate: β = 0.7818
#
# ============================================================
# COVARIATE BALANCE CHECK
# ============================================================
#
# Correlation between Treatment and Confounders:
# (Good balance: correlation close to 0 after GPS adjustment)
#        Confounder  Correlation_before  Correlation_after  Reduction
#       hour_of_day            0.025458           0.032396  -0.006938
# his_dwell_count_i            0.131971           0.165912  -0.033941
#   his_avg_delay_i            0.229679           0.301985  -0.072306
#   his_avg_dwell_i           -0.002313          -0.081541  -0.079228
#   is_morning_peak           -0.021282          -0.030064  -0.008782
#   is_evening_peak           -0.027324          -0.029914  -0.002591
#
# ============================================================
# SUMMARY: COMPARISON OF ALL METHODS
# ============================================================
#
#                                 Method  Coefficient β Controls Confounding Assumes linearity
#               1. Naive (No adjustment)       0.853288                   No               Yes
#           2. Regression (Linear model)       0.863720     Yes (parametric)               Yes
#         3. GPS (Nonparametric balance)       0.764091      Yes (balancing)     No (flexible)
# 4. Doubly Robust (GPS + Outcome model)       0.781763  Yes (doubly robust)         Partially
#
# Interpretation of coefficient β:
# Each 1-second increase in delay at stop i causes β seconds
# increase in delay at stop j (on average)
