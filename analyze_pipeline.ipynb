# %%
import sqlite3
import pandas as pd
db_path="workspace/database/gtfs_raw.db"
conn = sqlite3.connect(db_path)
pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", conn)
# Out:
#                     name
# 0            TripUpdates
# 1                 routes
# 2                 agency
# 3                  stops
# 4                  trips
# 5              stops_poi
# 6        TripUpdates_poi
# 7  TripUpdates_poi_joint
# 8             stop_pairs

# %%
from src.poi_filter import filter_trip_updates_poi
filter_trip_updates_poi(db_path)
# Out:
# Filtered to 7751703 trip updates in POI area
# Filtered to 212094 trip updates in POI area

# %%
from src.poi_joint import prepare_stop_pairs
ob_window=10*60
gap=1
prepare_stop_pairs(db_path, gap, ob_window)
# Out:
# created index for (trip_id, vehicle_id, start_date, stop_sequence)

# %%
df_pairs = pd.read_sql_query("SELECT * FROM stop_pairs limit 5", conn)
for column in df_pairs.columns:
    print(column)
# Out:
# trip_id
# start_date
# vehicle_id
# route_id
# line_name
# route_type
# stop_i
# seq_i
# arr_delay_i
# dep_delay_i
# arr_time_i
# duration_i
# his_dwell_count_i
# his_avg_delay_i
# stop_j
# seq_j
# arr_delay_j
# dep_delay_j
# arr_time_j
# duration_j
# travel_time
# delay_change
# hour_of_day
# day_of_week

# %%
import sqlite3
db_path = "workspace/database/gtfs_raw.db"
output_dir = "workspace/output"
conn = sqlite3.connect(db_path)

# Basic statistics
stats_query = """
SELECT 
    COUNT(*) as total_records,
    COUNT(DISTINCT trip_id) as n_trips,
    COUNT(DISTINCT stop_id) as n_stops,
    COUNT(DISTINCT start_date) as n_days,
    MIN(start_date) as first_date,
    MAX(start_date) as last_date
FROM TripUpdates_poi
"""
stats = pd.read_sql(stats_query, conn)
print(stats.to_string(index=False))
# Out:
#  total_records  n_trips  n_stops  n_days first_date last_date
#         212094     3101      817      12   20250310  20250508

# %%
# Delay statistics - fixed for SQLite
delay_stats = """
SELECT 
    AVG(arr_delay) as mean_delay,
    MIN(arr_delay) as min_delay,
    MAX(arr_delay) as max_delay,
    COUNT(CASE WHEN arr_delay > 60 THEN 1 END) as late_count,
    COUNT(CASE WHEN arr_delay < -60 THEN 1 END) as early_count,
    COUNT(CASE WHEN arr_delay BETWEEN -60 AND 60 THEN 1 END) as ontime_count,
    COUNT(*) as total_count,
    ROUND(100.0 * COUNT(CASE WHEN arr_delay > 60 THEN 1 END) / COUNT(*), 2) as late_pct,
    ROUND(100.0 * COUNT(CASE WHEN arr_delay < -60 THEN 1 END) / COUNT(*), 2) as early_pct,
    ROUND(100.0 * COUNT(CASE WHEN arr_delay BETWEEN -60 AND 60 THEN 1 END) / COUNT(*), 2) as ontime_pct
FROM TripUpdates_poi
WHERE arr_delay IS NOT NULL
"""

print("\nDelay Statistics:")
print("(Negative = Early, Positive = Late, unit: seconds)")
delay_df = pd.read_sql(delay_stats, conn)
print(delay_df.to_string(index=False))

# Compute std using pandas
all_delays = pd.read_sql("SELECT arr_delay FROM TripUpdates_poi WHERE arr_delay IS NOT NULL", conn)
print(f"\nStandard Deviation of Delays: {all_delays['arr_delay'].std():.2f} seconds")
# Out:
# Delay Statistics:
# (Negative = Early, Positive = Late, unit: seconds)
#  mean_delay  min_delay  max_delay  late_count  early_count  ontime_count  total_count  late_pct  early_pct  ontime_pct
#   96.530934      -4097       9280      109240        25143         77711       212094     51.51      11.85       36.64
#
# Standard Deviation of Delays: 219.17 seconds

# %%
db_path = "workspace/database/gtfs_raw.db"
output_dir = "workspace/output"
Path(output_dir).mkdir(parents=True, exist_ok=True)

# %%
db_path = "workspace/database/gtfs_raw.db"
gap = 1
ob_window = 20*60
output_dir = "workspace/output"
from src.statistical_learning import compare_methods
compare_methods(db_path, gap, output_dir)
# Out:
# created index for (trip_id, vehicle_id, start_date, stop_sequence)
# Loaded 173,737 observations
# Remained 173,737 observations after outlier filtering
# Treatment: delay_i (continuous, in seconds)
#   Mean: 106.01 seconds
#   Std: 208.32 seconds
#   Range: [-4097.00, 7537.00]
#
# Outcome: delay_j (continuous, in seconds)
#   Mean: 107.46 seconds
#   Std: 209.89 seconds
#
# Saved: /home/jinghan/projecttest/output/after_1_stop/treatment_outcome_distribution.png
#
# ============================================================
# IDENTIFYING CONFOUNDERS
# ============================================================
#
# Confounders included:
#   - hour_of_day
#   - his_dwell_count_i
#   - his_avg_delay_i
#   - his_avg_dwell_i
#   - is_morning_peak
#   - is_evening_peak
#
# Clean dataset: 173,737 observations
#
# ============================================================
# METHOD 1: NAIVE COMPARISON (BASELINE)
# ============================================================
# Naive estimate: β = 0.9153
# Interpretation: Each 1-second increase in delay_i is associated
#                 with 0.9153 seconds increase in delay_j
#
# ============================================================
# METHOD 2: REGRESSION ADJUSTMENT
# ============================================================
# Regression-adjusted estimate: β = 0.9223
# Interpretation: Controlling for confounders, each 1-second increase
#                 in delay_i causes 0.9223 seconds increase in delay_j
#
# Regression coefficients:
#   hour_of_day: 12.3706
#   his_dwell_count_i: -3.0825
#   his_avg_delay_i: -7.2672
#   his_avg_dwell_i: 1.0405
#   is_morning_peak: 9.3416
#   is_evening_peak: -4.2861
#
# ============================================================
# METHOD 3: GENERALIZED PROPENSITY SCORE (GPS)
# ============================================================
# Reference: Hirano & Imbens (2004)
#
# Step 1: Estimating treatment model E[D|X]...
# Treatment model R²: 0.0430
# Residual std (σ): 203.79
#
# Step 2: Calculating Generalized Propensity Score...
# GPS range: [0.000000, 0.001958]
# Mean GPS: 0.001604
# Saved: /home/jinghan/projecttest/output/after_1_stop/gps_distribution.png
#
# Step 3: Trimming for common support...
# Common support: GPS in [0.000116, 0.001957]
# Observations retained: 165,049 (95.0%)
#
# === Analysis of Trimmed Observations ===
# Trimmed: 8,688 (5.0%)
# Trimmed mean delay_i: 411.90
# Trimmed mean delay_j: 420.70
# Retained mean delay_i: 89.91
# Retained mean delay_j: 90.97
#
# Step 4: Estimating dose-response function...
# GPS-adjusted estimate: β = 0.8472
# Interpretation: Balancing treatment assignment, each 1-second increase
#                 in delay_i causes 0.8472 seconds increase in delay_j
#
# Step 5: Estimating dose-response curve...
# Saved: /home/jinghan/projecttest/output/after_1_stop/dose_response_curve.png
#
# ============================================================
# METHOD 4: DOUBLY ROBUST ESTIMATION (GPS + OUTCOME MODEL)
# ============================================================
#
# Step 1: Fitting outcome regression model E[Y|D,X]...
#
# Step 2: Computing doubly robust estimate...
# Doubly Robust estimate: β = 0.8477
#
# ============================================================
# COVARIATE BALANCE CHECK
# ============================================================
#
# Correlation between Treatment and Confounders:
# (Good balance: correlation close to 0 after GPS adjustment)
#        Confounder  Correlation_before  Correlation_after  Reduction
#       hour_of_day            0.010436           0.024766  -0.014330
# his_dwell_count_i            0.072778           0.102020  -0.029242
#   his_avg_delay_i            0.195857           0.290375  -0.094518
#   his_avg_dwell_i           -0.008642           0.003502   0.005140
#   is_morning_peak            0.001973          -0.013127  -0.011154
#   is_evening_peak           -0.012923          -0.002846   0.010077
#
# Saved: /home/jinghan/projecttest/output/after_1_stop/covariate_balance_gps.png
#
# ============================================================
# SUMMARY: COMPARISON OF ALL METHODS
# ============================================================
#
#                                 Method  Coefficient β Controls Confounding Assumes linearity
#               1. Naive (No adjustment)       0.915276                   No               Yes
#           2. Regression (Linear model)       0.922255     Yes (parametric)               Yes
#         3. GPS (Nonparametric balance)       0.847240      Yes (balancing)     No (flexible)
# 4. Doubly Robust (GPS + Outcome model)       0.847701  Yes (doubly robust)         Partially
#
# Interpretation of coefficient β:
# Each 1-second increase in delay at stop i causes β seconds
# increase in delay at stop j (on average)
#
# Saved: /home/jinghan/projecttest/output/after_1_stop/causal_estimates_comparison.png

# %%
gap = 2
from src.statistical_learning import compare_methods
compare_methods(db_path, gap, output_dir)
# Out:
# created index for (trip_id, vehicle_id, start_date, stop_sequence)
# Loaded 154,497 observations
# Remained 154,497 observations after outlier filtering
# Treatment: delay_i (continuous, in seconds)
#   Mean: 107.15 seconds
#   Std: 207.09 seconds
#   Range: [-4097.00, 7523.00]
#
# Outcome: delay_j (continuous, in seconds)
#   Mean: 109.07 seconds
#   Std: 210.82 seconds
#
# Saved: /home/jinghan/projecttest/output/after_2_stop/treatment_outcome_distribution.png
#
# ============================================================
# IDENTIFYING CONFOUNDERS
# ============================================================
#
# Confounders included:
#   - hour_of_day
#   - his_dwell_count_i
#   - his_avg_delay_i
#   - his_avg_dwell_i
#   - is_morning_peak
#   - is_evening_peak
#
# Clean dataset: 154,497 observations
#
# ============================================================
# METHOD 1: NAIVE COMPARISON (BASELINE)
# ============================================================
# Naive estimate: β = 0.8931
# Interpretation: Each 1-second increase in delay_i is associated
#                 with 0.8931 seconds increase in delay_j
#
# ============================================================
# METHOD 2: REGRESSION ADJUSTMENT
# ============================================================
# Regression-adjusted estimate: β = 0.9010
# Interpretation: Controlling for confounders, each 1-second increase
#                 in delay_i causes 0.9010 seconds increase in delay_j
#
# Regression coefficients:
#   hour_of_day: 14.7647
#   his_dwell_count_i: -1.4954
#   his_avg_delay_i: -9.0484
#   his_avg_dwell_i: -0.4820
#   is_morning_peak: 11.8387
#   is_evening_peak: -5.9057
#
# ============================================================
# METHOD 3: GENERALIZED PROPENSITY SCORE (GPS)
# ============================================================
# Reference: Hirano & Imbens (2004)
#
# Step 1: Estimating treatment model E[D|X]...
# Treatment model R²: 0.0434
# Residual std (σ): 202.54
#
# Step 2: Calculating Generalized Propensity Score...
# GPS range: [0.000000, 0.001970]
# Mean GPS: 0.001613
# Saved: /home/jinghan/projecttest/output/after_2_stop/gps_distribution.png
#
# Step 3: Trimming for common support...
# Common support: GPS in [0.000112, 0.001969]
# Observations retained: 146,772 (95.0%)
#
# === Analysis of Trimmed Observations ===
# Trimmed: 7,725 (5.0%)
# Trimmed mean delay_i: 410.85
# Trimmed mean delay_j: 418.44
# Retained mean delay_i: 91.16
# Retained mean delay_j: 92.79
#
# Step 4: Estimating dose-response function...
# GPS-adjusted estimate: β = 0.8102
# Interpretation: Balancing treatment assignment, each 1-second increase
#                 in delay_i causes 0.8102 seconds increase in delay_j
#
# Step 5: Estimating dose-response curve...
# Saved: /home/jinghan/projecttest/output/after_2_stop/dose_response_curve.png
#
# ============================================================
# METHOD 4: DOUBLY ROBUST ESTIMATION (GPS + OUTCOME MODEL)
# ============================================================
#
# Step 1: Fitting outcome regression model E[Y|D,X]...
#
# Step 2: Computing doubly robust estimate...
# Doubly Robust estimate: β = 0.8154
#
# ============================================================
# COVARIATE BALANCE CHECK
# ============================================================
#
# Correlation between Treatment and Confounders:
# (Good balance: correlation close to 0 after GPS adjustment)
#        Confounder  Correlation_before  Correlation_after  Reduction
#       hour_of_day            0.018003           0.035229  -0.017226
# his_dwell_count_i            0.078481           0.112633  -0.034151
#   his_avg_delay_i            0.195119           0.289894  -0.094775
#   his_avg_dwell_i           -0.011243          -0.057919  -0.046676
#   is_morning_peak           -0.004915          -0.022506  -0.017591
#   is_evening_peak           -0.006440           0.006881  -0.000441
#
# Saved: /home/jinghan/projecttest/output/after_2_stop/covariate_balance_gps.png
#
# ============================================================
# SUMMARY: COMPARISON OF ALL METHODS
# ============================================================
#
#                                 Method  Coefficient β Controls Confounding Assumes linearity
#               1. Naive (No adjustment)       0.893145                   No               Yes
#           2. Regression (Linear model)       0.901024     Yes (parametric)               Yes
#         3. GPS (Nonparametric balance)       0.810239      Yes (balancing)     No (flexible)
# 4. Doubly Robust (GPS + Outcome model)       0.815390  Yes (doubly robust)         Partially
#
# Interpretation of coefficient β:
# Each 1-second increase in delay at stop i causes β seconds
# increase in delay at stop j (on average)
#
# Saved: /home/jinghan/projecttest/output/after_2_stop/causal_estimates_comparison.png

# %%
gap = 3
from src.statistical_learning import compare_methods
compare_methods(db_path, gap, output_dir)
# Out:
# created index for (trip_id, vehicle_id, start_date, stop_sequence)
# Loaded 136,949 observations
# Remained 136,949 observations after outlier filtering
# Treatment: delay_i (continuous, in seconds)
#   Mean: 108.01 seconds
#   Std: 206.39 seconds
#   Range: [-4097.00, 7523.00]
#
# Outcome: delay_j (continuous, in seconds)
#   Mean: 108.90 seconds
#   Std: 212.26 seconds
#
# Saved: /home/jinghan/projecttest/output/after_3_stop/treatment_outcome_distribution.png
#
# ============================================================
# IDENTIFYING CONFOUNDERS
# ============================================================
#
# Confounders included:
#   - hour_of_day
#   - his_dwell_count_i
#   - his_avg_delay_i
#   - his_avg_dwell_i
#   - is_morning_peak
#   - is_evening_peak
#
# Clean dataset: 136,949 observations
#
# ============================================================
# METHOD 1: NAIVE COMPARISON (BASELINE)
# ============================================================
# Naive estimate: β = 0.8681
# Interpretation: Each 1-second increase in delay_i is associated
#                 with 0.8681 seconds increase in delay_j
#
# ============================================================
# METHOD 2: REGRESSION ADJUSTMENT
# ============================================================
# Regression-adjusted estimate: β = 0.8776
# Interpretation: Controlling for confounders, each 1-second increase
#                 in delay_i causes 0.8776 seconds increase in delay_j
#
# Regression coefficients:
#   hour_of_day: 19.9735
#   his_dwell_count_i: -1.4672
#   his_avg_delay_i: -11.0306
#   his_avg_dwell_i: -0.6512
#   is_morning_peak: 16.7189
#   is_evening_peak: -7.6085
#
# ============================================================
# METHOD 3: GENERALIZED PROPENSITY SCORE (GPS)
# ============================================================
# Reference: Hirano & Imbens (2004)
#
# Step 1: Estimating treatment model E[D|X]...
# Treatment model R²: 0.0441
# Residual std (σ): 201.79
#
# Step 2: Calculating Generalized Propensity Score...
# GPS range: [0.000000, 0.001977]
# Mean GPS: 0.001617
# Saved: /home/jinghan/projecttest/output/after_3_stop/gps_distribution.png
#
# Step 3: Trimming for common support...
# Common support: GPS in [0.000108, 0.001977]
# Observations retained: 130,101 (95.0%)
#
# === Analysis of Trimmed Observations ===
# Trimmed: 6,848 (5.0%)
# Trimmed mean delay_i: 414.12
# Trimmed mean delay_j: 412.60
# Retained mean delay_i: 91.90
# Retained mean delay_j: 92.91
#
# Step 4: Estimating dose-response function...
# GPS-adjusted estimate: β = 0.7679
# Interpretation: Balancing treatment assignment, each 1-second increase
#                 in delay_i causes 0.7679 seconds increase in delay_j
#
# Step 5: Estimating dose-response curve...
# Saved: /home/jinghan/projecttest/output/after_3_stop/dose_response_curve.png
#
# ============================================================
# METHOD 4: DOUBLY ROBUST ESTIMATION (GPS + OUTCOME MODEL)
# ============================================================
#
# Step 1: Fitting outcome regression model E[Y|D,X]...
#
# Step 2: Computing doubly robust estimate...
# Doubly Robust estimate: β = 0.7855
#
# ============================================================
# COVARIATE BALANCE CHECK
# ============================================================
#
# Correlation between Treatment and Confounders:
# (Good balance: correlation close to 0 after GPS adjustment)
#        Confounder  Correlation_before  Correlation_after  Reduction
#       hour_of_day            0.024315           0.044355  -0.020041
# his_dwell_count_i            0.081528           0.117639  -0.036111
#   his_avg_delay_i            0.195694           0.291481  -0.095787
#   his_avg_dwell_i           -0.011966          -0.063883  -0.051917
#   is_morning_peak           -0.010905          -0.031192  -0.020287
#   is_evening_peak           -0.001387           0.015586  -0.014199
#
# Saved: /home/jinghan/projecttest/output/after_3_stop/covariate_balance_gps.png
#
# ============================================================
# SUMMARY: COMPARISON OF ALL METHODS
# ============================================================
#
#                                 Method  Coefficient β Controls Confounding Assumes linearity
#               1. Naive (No adjustment)       0.868102                   No               Yes
#           2. Regression (Linear model)       0.877582     Yes (parametric)               Yes
#         3. GPS (Nonparametric balance)       0.767899      Yes (balancing)     No (flexible)
# 4. Doubly Robust (GPS + Outcome model)       0.785528  Yes (doubly robust)         Partially
#
# Interpretation of coefficient β:
# Each 1-second increase in delay at stop i causes β seconds
# increase in delay at stop j (on average)
#
# Saved: /home/jinghan/projecttest/output/after_3_stop/causal_estimates_comparison.png
